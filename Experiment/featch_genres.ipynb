# %%
# !pip install torch torchvision torchaudio --quiet
# !pip install transformers --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.8 MB/s eta 0:00:00

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Device name: Tesla T4

# %%
import json
import ast

path = "/content/genre_keywords.json"
with open(path, "r", encoding="utf-8", errors="ignore") as f:
    raw_text = f.read()


GENRE_KEYWORDS = ast.literal_eval(raw_text)
print(type(GENRE_KEYWORDS))
print(GENRE_KEYWORDS)
# Out:
# <class 'dict'>
# {'Fantasy': ['magic', 'dragon', 'wizard', 'elf', 'fairy', 'sorcery', 'spell', 'kingdom', 'orc', 'mythic', 'faerie', 'portal', 'elemental', 'urban fantasy', 'epic fantasy', 'high fantasy', 'dark fantasy'], 'Science Fiction': ['space', 'robot', 'alien', 'dystopian', 'cyberpunk', 'futuristic', 'time travel', 'ai', 'post‑apocalyptic', 'interstellar', 'galactic', 'terraform', 'hard sci‑fi', 'soft sci‑fi', 'space opera'], 'Mystery & Thriller': ['detective', 'murder', 'crime', 'thriller', 'suspense', 'investigation', 'whodunit', 'noir', 'espionage', 'conspiracy', 'cozy mystery', 'psychological thriller', 'legal thriller'], 'Romance': ['romance', 'love', 'affair', 'passion', 'relationship', 'heart', 'bridgerton', 'historical romance', 'contemporary romance', 'romantic suspense', 'erotic', 'paranormal romance'], 'Horror': ['ghost', 'haunted', 'vampire', 'werewolf', 'zombie', 'supernatural', 'demon', 'possession', 'nightmare', 'gore', 'creepy', 'cosmic horror', 'slasher', 'body horror'], 'Historical Fiction': ['renaissance', 'empire', 'civil war', 'victorian', 'viking', 'ottoman', 'war saga', 'period piece', 'time slip'], 'Literary Fiction': ['literary', 'bildungsroman', 'family saga', 'psychological', 'existential', 'stream of consciousness'], 'Young Adult': ['teen', 'high school', 'coming of age', 'ya', 'youth', 'dystopian young adult', 'teen drama', 'adolescent fiction'], 'Children’s Literature': ['picture book', 'storybook', 'bedtime', 'middle grade', 'chapter book', 'fairytale retelling'], 'Biography & Memoir': ['memoir', 'autobiography', 'life of', 'diary', 'journal', 'profile', 'chronicle', 'oral history'], 'Self‑Help & Personal Development': ['self‑help', 'motivation', 'habits', 'productivity', 'mindfulness', 'growth', 'inspiration', 'resilience', 'confidence', 'goal‑setting'], 'Health & Wellness': ['health', 'fitness', 'diet', 'wellness', 'medicine', 'nutrition', 'yoga', 'meditation', 'therapy', 'well‑being', 'mental health', 'alternative medicine'], 'Cooking & Food': ['cookbook', 'recipe', 'cooking', 'baking', 'kitchen', 'chef', 'gourmet', 'vegetarian', 'vegan', 'barbecue', 'wine', 'cocktail'], 'Travel & Adventure': ['travel', 'tour', 'trip', 'backpacking', 'guidebook', 'expedition', 'road trip', 'journey', 'wanderlust', 'travel memoir'], 'History': ['history', 'ancient', 'medieval', 'civilization', 'war', 'empire', 'revolution', 'archaeology', 'historical account'], 'Politics & Current Affairs': ['politics', 'election', 'government', 'policy', 'geopolitics', 'democracy', 'human rights', 'international relations'], 'Business & Economics': ['business', 'economics', 'management', 'finance', 'leadership', 'entrepreneur', 'startup', 'marketing', 'investment', 'corporate', 'econometrics'], 'Science & Technology': ['science', 'physics', 'quantum', 'chemistry', 'biology', 'technology', 'engineering', 'robotics', 'computer', 'data science', 'astronomy', 'climate change', 'ai', 'coding'], 'Education & Reference': ['textbook', 'manual', 'course', 'reference', 'academic', 'study', 'curriculum', 'handbook', 'guide', 'cheat sheet'], 'Religion & Spirituality': ['religion', 'spiritual', 'faith', 'bible', 'christianity', 'buddhism', 'hinduism', 'meditation', 'scripture', 'theology'], 'Poetry & Essays': ['poetry', 'poem', 'verse', 'haiku', 'limerick', 'sonnet', 'essay', 'memoir', 'prose', 'anthology', 'lyric'], 'Graphic Novel & Comics': ['comic', 'graphic novel', 'manga', 'webtoon', 'illustrated', 'superhero', 'graphic memoir'], 'Humor & Satire': ['humor', 'satire', 'parody', 'funny', 'joke', 'comedy', 'wit', 'quirky', 'cartoon'], 'Parenting & Relationships': ['parenting', 'family', 'marriage', 'childcare', 'custody', 'relationship advice', 'pregnancy'], 'Sports & Recreation': ['sports', 'football', 'soccer', 'basketball', 'baseball', 'outdoors', 'fishing', 'hiking', 'climbing', 'fitness guide'], 'Arts & Photography': ['art', 'photography', 'painting', 'drawing', 'museum', 'gallery', 'artist biography', 'graphic design'], 'Music & Performing A ...

# %%
# 1) Load data
import pandas as pd
from tqdm import tqdm
df = pd.read_csv("/content/books_isbn_title.csv")
titles = df["title"].fillna("").astype(str).tolist()
candidate_labels = list(GENRE_KEYWORDS.keys())

# %%
from transformers import pipeline

classifier = pipeline(
    "zero-shot-classification",
    model="typeform/distilbert-base-uncased-mnli",  # lightweight NLI
    framework="pt",    # force PyTorch
    device=0,          # GPU device 0
    batch_size=64
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/258 [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0

# %%
# Classify in batches
batch_size = 128
preds = []
for i in tqdm(range(0, len(titles), batch_size)):
    batch = titles[i:i+batch_size]
    outputs = classifier(batch, candidate_labels, multi_label=False)

    # When using batches, outputs is a list of dicts — pick top label per example
    if isinstance(outputs, list):
        preds.extend([out["labels"][0] for out in outputs])
    else:
        preds.append(outputs["labels"][0])

# Save to CSV
df["predicted_genre"] = preds
df.to_csv("books_with_genres.csv", index=False)
# Out:
# 100%|██████████| 2120/2120 [1:48:02<00:00,  3.06s/it]

# %%
df.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                     predicted_genre
# 0                           History
# 1  Self‑Help & Personal Development
# 2  Self‑Help & Personal Development
# 3                           History
# 4                   Science Fiction

# %%
df.sample(20)
# Out:
#               ISBN                                              title  \
# 190989  0747273847                                    High on a Cliff
# 236697  0965766624  The Relationship Toolbox: Tools for Love, Heal...
# 145110  0806520434  Love, Sex, and Magick: Exploring the Spiritual...
# 110617  0062554883           Addictive Personality Understanding Comp
# 90362   0898706025  Celine: Sister Genevieve of the Holy Face : Si...
# 119859  9010029425  Waanzin en moederliefde &amp; Dorpsgeheimen (E...
# 56907   1400031427  In Search of Zarathustra : Across Iran and Cen...
# 154274  0553487280  No More Mr. Nice Guy (Sweet Valley Jr. High No...
# 219818  0310704618            Even Fish Slappers Need a Second Chance
# 54505   0871358816                           The Stars My Destination
# 269903  0671766066  THREE HUNDRED AND SIXTY FIVE STARRY NIGHTS : A...
# 100801  0195002679  Egypt of the Pharaohs: An Introduction (Galaxy...
# 85065   0156745925                   Principles of Literary Criticism
# 1648    0007108648             Whizzard (Tales of the Dark Forest S.)
# 194572  0785804218                          Italian Farmhouse Cooking
# 164793  1931313644                                    Arch of Triumph
# 50212   0515087521                             Something of the Night
# 145461  0812536738                               The Door Into Shadow
# 172280  0670306622                                  Family Sabbatical
# 72847   2266096400                         Le CrÃ?Â©puscule des elfes
#
#                          predicted_genre
# 190989  Self‑Help & Personal Development
# 236697  Self‑Help & Personal Development
# 145110         Parenting & Relationships
# 110617  Self‑Help & Personal Development
# 90362                            Romance
# 119859           Music & Performing Arts
# 56907         Politics & Current Affairs
# 154274         Parenting & Relationships
# 219818                    Cooking & Food
# 54505                 Travel & Adventure
# 269903                           History
# 100801                           History
# 85065   Self‑Help & Personal Development
# 1648                             Fantasy
# 194572                    Cooking & Food
# 164793                           History
# 50212                     Cooking & Food
# 145461  Self‑Help & Personal Development
# 172280  Self‑Help & Personal Development
# 72847                  Health & Wellness

# %%
df.to_csv("genres.csv", index=False)

# %%
df.isna().sum()
# Out:
# ISBN               0
# title              0
# predicted_genre    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from google.colab import files
files.download("genres.csv")
